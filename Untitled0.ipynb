# %% [markdown]
# <a href="https://colab.research.google.com/github/Riskev02/Riskev02/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageOps
# %matplotlib inline

# %%
img = files.upload()
# Out:
#      <input type="file" id="files-9f515627-2e28-44f3-84a2-4b926e958873" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f515627-2e28-44f3-84a2-4b926e958873">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screen Shot 2022-04-09 at 21.59.10.png to Screen Shot 2022-04-09 at 21.59.10.png

# %%
! ls
# Out:
# 'imgres?imgurl=https%3A%2F%2Flogos-world.net%2Fwp-content%2Fuploads%2F2021%2F10%2FPython-Symbol.png'
# 'imgres?imgurl=https%3A%2F%2Flumiere-a.akamaihd.net%2Fv1%2Fimages%2Fh_cars3_19643_6fbffafe.jpeg'
#  sample_data
# 'Screen Shot 2022-04-09 at 21.59.10.png'

# %%
image = Image.open('Screen Shot 2022-04-09 at 21.59.10.png')
image = np.asarray(image)

# %%
plt.imshow(image)

# %%
type(image)
# Out:
# numpy.ndarray
